# %% [markdown]
# <a href="https://colab.research.google.com/github/opherdonchin/ModelsOfTheMotorSystems2021-2/blob/master/In_class_internal_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# # In class internal models
# ## Do an inverse model calculation
#
# For a 2-link arm with
#
# - Upper arm length: $l_1 = 0.34 ~\textrm{m}$
# - Forearm length: $l_2 = 0.46 ~\textrm{m}$
# - Joint position: $\theta = (45, 45)$ in degrees
# - Joint velocity: $\dot{\theta} = (−60, 14)$ in $\textrm{degree/s}$
#
# We want a hand acceleration of: $\ddot{x} = (-1000, 200)$ in $\textrm{degree/s$^2$}$
#
# Find the torque $\tau$ on the joint required to generate this acceleration.

# %% [markdown]
# ## Assume the lack of an internal model
#
# One option for modeling the lack of an internal model is assuming that it only knows about diagnoal terms in the matrix.
#
# $
# \begin{align}
# M_{internal\  model} & = \text{diag}(M) \\
# C_{internal\  model} & = \text{diag}(C)
# \end{align}
# $
#
# Find the torque $\tau_i$ that would be generated by this internal model to generate the acceleration.

# %% [markdown]
# ## Calculate the error in the direction
#
# Caculate the direction that the person is trying to accelerate their hand and the direction that they will accelerate it in case of the wrong internal model.
#
# How big is the angular difference in the direction of acceleration?
